# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 19.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 20.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 47.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.4 MB/s eta 0:00:00

# %%
! pip install pyngrok

# %%
from pyngrok import ngrok

# %%
#Get your Auth_token @ https://dashboard.ngrok.com/login
ngrok.set_auth_token("2j0yfTqt8PY5E7SbDQsHXaB2YcM_86cUFe8jHbKd93VVuez2E")

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Data Mining project/
# !nohup streamlit run MyApp.py --server.port 80 &
url = ngrok.connect()
print(url)
# Out:
# /content/drive/MyDrive/Colab Notebooks/Data Mining project
# nohup: appending output to 'nohup.out'
# NgrokTunnel: "https://48af-34-125-190-181.ngrok-free.app" -> "http://localhost:80"

# %%
ngrok.kill()
